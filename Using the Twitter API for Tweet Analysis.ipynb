# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os

# %%
if not os.path.exists('secret_twitter_credentials.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = ''
    Twitter['Consumer Secret'] = ''
    Twitter['Access Token'] = ''
    Twitter['Access Token Secret'] = ''
    with open('secret_twitter_credentials.pkl','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('secret_twitter_credentials.pkl','rb'))

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
# !pip install twitter
# Out:
# Requirement already satisfied: twitter in c:\users\samuel\anaconda3\lib\site-packages (1.18.0)
# You are using pip version 18.0, however version 18.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x0000020B2F9A5B38>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977
BRA_WOE_ID = 23424768
SAOPAULO_ID = 455827

# %% [markdown]
# Look for the WOEID for [san-diego](http://woeid.rosselliot.co.nz/lookup/san%20diego%20%20ca)
#
# You can change it to another location.

# %%
LOCAL_WOE_ID=2487889

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)
bra_trends = twitter_api.trends.place(_id=BRA_WOE_ID)
localSP_trends = twitter_api.trends.place(_id=SAOPAULO_ID)

# %%
world_trends[:2]
# Out:
# [{'trends': [{'name': '#مصري_يفطر_مع_سعوديه',
#     'url': 'http://twitter.com/search?q=%23%D9%85%D8%B5%D8%B1%D9%8A_%D9%8A%D9%81%D8%B7%D8%B1_%D9%85%D8%B9_%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D9%87',
#     'promoted_content': None,
#     'query': '%23%D9%85%D8%B5%D8%B1%D9%8A_%D9%8A%D9%81%D8%B7%D8%B1_%D9%85%D8%B9_%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D9%87',
#     'tweet_volume': 56117},
#    {'name': '#FelizDomingo',
#     'url': 'http://twitter.com/search?q=%23FelizDomingo',
#     'promoted_content': None,
#     'query': '%23FelizDomingo',
#     'tweet_volume': 16614},
#    {'name': '#9Eylül',
#     'url': 'http://twitter.com/search?q=%239Eyl%C3%BCl',
#     'promoted_content': None,
#     'query': '%239Eyl%C3%BCl',
#     'tweet_volume': 128513},
#    {'name': '#عنوان_حياتك',
#     'url': 'http://twitter.com/search?q=%23%D8%B9%D9%86%D9%88%D8%A7%D9%86_%D8%AD%D9%8A%D8%A7%D8%AA%D9%83',
#     'promoted_content': None,
#     'query': '%23%D8%B9%D9%86%D9%88%D8%A7%D9%86_%D8%AD%D9%8A%D8%A7%D8%AA%D9%83',
#     'tweet_volume': 12222},
#    {'name': '#تجمع_النباتيين_العرب',
#     'url': 'http://twitter.com/search?q=%23%D8%AA%D8%AC%D9%85%D8%B9_%D8%A7%D9%84%D9%86%D8%A8%D8%A7%D8%AA%D9%8A%D9%8A%D9%86_%D8%A7%D9%84%D8%B9%D8%B1%D8%A8',
#     'promoted_content': None,
#     'query': '%23%D8%AA%D8%AC%D9%85%D8%B9_%D8%A7%D9%84%D9%86%D8%A8%D8%A7%D8%AA%D9%8A%D9%8A%D9%86_%D8%A7%D9%84%D8%B9%D8%B1%D8%A8',
#     'tweet_volume': 27250},
#    {'name': '달고나',
#     'url': 'http://twitter.com/search?q=%EB%8B%AC%EA%B3%A0%EB%82%98',
#     'promoted_content': None,
#     'query': '%EB%8B%AC%EA%B3%A0%EB%82%98',
#     'tweet_volume': None},
#    {'name': 'VIVA EL REY',
#     'url': 'http://twitter.com/search?q=%22VIVA+EL+REY%22',
#     'promoted_content': None,
#     'query': '%22VIVA+EL+REY%22',
#     'tweet_volume': 31812},
#    {'name': 'リズムゲー',
#     'url': 'http://twitter.com/search?q=%E3%83%AA%E3%82%BA%E3%83%A0%E3%82%B2%E3%83%BC',
#     'promoted_content': None,
#     'query': '%E3%83%AA%E3%82%BA%E3%83%A0%E3%82%B2%E3%83%BC',
#     'tweet_volume': None},
#    {'name': '京葉線',
#     'url': 'http://twitter.com/search?q=%E4%BA%AC%E8%91%89%E7%B7%9A',
#     'promoted_content': None,
#     'query': '%E4%BA%AC%E8%91%89%E7%B7%9A',
#     'tweet_volume': 11516},
#    {'name': '横浜優勝',
#     'url': 'http://twitter.com/search?q=%E6%A8%AA%E6%B5%9C%E5%84%AA%E5%8B%9D',
#     'promoted_content': None,
#     'query': '%E6%A8%AA%E6%B5%9C%E5%84%AA%E5%8B%9D',
#     'tweet_volume': None},
#    {'name': 'Trust me',
#     'url': 'http://twitter.com/search?q=%22Trust+me%22',
#     'promoted_content': None,
#     'query': '%22Trust+me%22',
#     'tweet_volume': 60197},
#    {'name': 'Harry Maguire',
#     'url': 'http://twitter.com/search?q=%22Harry+Maguire%22',
#     'promoted_content': None,
#     'query': '%22Harry+Maguire%22',
#     'tweet_volume': None},
#    {'name': 'Hanuma Vihari',
#     'url': 'http://twitter.com/search?q=%22Hanuma+Vihari%22',
#     'promoted_content': None,
#     'query': '%22Hanuma+Vihari%22',
#     'tweet_volume': None},
#    {'name': 'Manuela Carmena',
#     'url': 'http://twitter.com/search?q=%22Manuela+Carmena%22',
#     'promoted_content': None,
#     'query': '%22Manuela+Carmena%22',
#     'tweet_volume': None},
#    {'name': 'ヒプマイゲーム化',
#     'url': 'http://twitter.com/search?q=%E3%83%92%E3%83%97%E3%83%9E%E3%82%A4%E3%82%B2%E3%83%BC%E3%83%A0%E5%8C%96',
#     'promoted_content': None,
#     'query': '%E3%83%92%E3%83%97%E3%83%9E%E3%82%A4%E3%82%B2%E3%83%BC%E3%83%A0%E5%8C%96',
#     'tweet_volume': None},
#    {'name': 'SS3A',
#     'url': 'http://twitter.com/search?q=SS3A',
#     'promoted_content': None,
#     'query': 'SS3A',
#     'tweet_volume': 173355},
#    {'name': 'Delhi NCR',
#     'url': 'http://twitter.com/search?q=%22Delhi+NCR%22',
#     'promoted_content': None,
#     'query': '%22Delhi+NCR%22',
#     'tweet_volume': None},
#    {'name': 'Kızlar TwitarttirComda',
#     'url': 'http://twitter.com/search?q=%22K%C4%B1zlar+TwitarttirComda%22',
#     'promoted_content': None,
#     'query': '%22K%C4%B1zlar+TwitarttirComda%22',
#     'tweet_volume': None},
#    {'name': '#あなたの人生を一文字で要約する',
#     'url': 'http://twitter.com/search?q=%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AE%E4%BA%BA%E7%94%9F%E3%82%92%E4%B8%80%E6%96%87%E5%AD%97%E3%81%A7%E8%A6%81%E7%B4%84%E3%81%99%E3%82%8B',
#     'promoted_content': None,
#     'query': '%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AE%E4%BA%BA%E7%94%9F%E3%82%92%E4%B8%80%E6%96%87%E5%AD%97%E3%81%A7%E8%A6%81%E7%B4%84%E3%81%99%E3%82%8B',
#     'tweet_volume': 10602},
#    {'name': '#村を焼くなら',
#     'url': 'http://twitter.com/search?q=%23%E6%9D%91%E3%82%92%E7%84%BC%E3%81%8F%E3%81%AA%E3%82%89',
#     'promoted_content': None,
#     'query': '%23%E6%9D%91%E3%82%92%E7%84%BC%E3%81%8F%E3%81%AA%E3%82%89',
#     'tweet_volume': 37898},
#    {'name': '#SanMarinoGP',
#     'url': 'http://twitter.com/search?q=%23SanMarinoGP',
#     'promoted_content': None,
#     'query': '%23SanMarinoGP',
#     'tweet_volume': 36991},
#    {'name': '#معني_الرجوله',
#     'url': 'http://twitter.com/search?q=%23%D9%85%D8%B9%D9%86%D9%8A_%D8%A7%D9%84%D8%B1%D8%AC%D9%88%D9%84%D9%87',
#     'promoted_content': None,
#     'query': '%23%D9%85%D8%B9%D9%86%D9%8A_%D8%A7%D9%84%D8%B1%D8%AC%D9%88%D9%84%D9%87',
#     'tweet_volume': None},
#    {'name': '#あなたがポケモンにいたら',
#     'url': 'http://twitter.com/search?q=%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%8C%E3%83%9D%E3%82%B1%E3%83%A2%E3%83%B3%E3%81%AB%E3%81%84%E3%81%9F%E3%82%89',
#     'promoted_content': None,
#     'query': '%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%8C%E3%83%9D%E3%82%B1%E3%83%A2%E3%83%B3%E3%81%AB%E3%81%84%E3%81%9F%E3%82%89',
#     'tweet_volume': 25465},
#    {'name': '#西郷どん',
#     'url': 'http://twitter.com/search?q=%23%E8%A5%BF%E9%83%B7%E3%81%A9%E3%82%93',
#     'promoted_content': None,
#     'query': '%23%E8%A5%BF%E9%83%B7%E3%81%A9%E3%82%93',
#     'tweet_volume': 16416},
#    {'name': '#SundayMorning',
#     'url': 'http://twitter.com/search?q=%23SundayMorning',
#     'promoted_content': None,
#     'query': '%23SundayMorning',
#     'tweet_volume': 19090},
#    {'name': '#GreatNorthRun',
#     'url': 'http://twitter.com/search?q=%23GreatNorthRun',
#     'promoted_content': None,
#     'query': '%23GreatNorthRun',
#     'tweet_volume': 13094},
#    {'name': '#이_해시를_보면_무조건_프사캐입',
#     'url': 'http://twitter.com/search?q=%23%EC%9D%B4_%ED%95%B4%EC%8B%9C%EB%A5%BC_%EB%B3%B4%EB%A9%B4_%EB%AC%B4%EC%A1%B0%EA%B1%B4_%ED%94%84%EC%82%AC%EC%BA%90%EC%9E%85',
#     'promoted_content': None,
#     'query': '%23%EC%9D%B4_%ED%95%B4%EC%8B%9C%EB%A5%BC_%EB%B3%B4%EB%A9%B4_%EB%AC%B4%EC%A1%B0%EA%B1%B4_%ED%94%84%EC%82%AC%EC%BA%90%EC%9E%85',
#     'tweet_volume': 11780},
#    {'name': '#MasterChefJuniorThailand',
#     'url': 'http://twitter.com/search?q=%23MasterChefJuniorThailand',
#     'promoted_content': None,
#     'query': '%23MasterChefJuniorThailand',
#     'tweet_volume': 43833},
#    {'name': '#あなたに会いたいフォロワーさん',
#     'url': 'http://twitter.com/search?q=%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AB%E4%BC%9A%E3%81%84%E3%81%9F%E3%81%84%E3%83%95%E3%82%A9%E3%83%AD%E3%83%AF%E3%83%BC%E3%81%95%E3%82%93',
#     'promoted_content': None,
#     'query': '%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AB%E4%BC%9A%E3%81%84%E3%81%9F%E3%81%84%E3%83%95%E3%82%A9%E3%83%AD%E3%83%AF%E3%83%BC%E3%81%95%E3%82%93',
#     'tweet_volume': None},
#    {'name': '#地球征服',
#     'url': 'http://twitter.com/search?q=%23%E5%9C%B0%E7%90%83%E5%BE%81%E6%9C%8D',
#     'promoted_content': None,
#     'query': '%23%E5%9C%B0%E7%90%83%E5%BE%81%E6%9C%8D',
#     'tweet_volume': 21971},
#    {'name': '#100DíasSinRumbo',
#     'url': 'http://twitter.com/search?q=%23100D%C3%ADasSinRumbo',
#     'promoted_content': None,
#     'query': '%23100D%C3%ADasSinRumbo',
#     'tweet_volume': 15417},
#    {'name': '#TheClashBattleToEight',
#     'url': 'http://twitter.com/search?q=%23TheClashBattleToEight',
#     'promoted_content': None,
#     'query': '%23TheClashBattleToEight',
#     'tweet_volume': 12736},
#    {'name': '#この世界の片隅に',
#     'url': 'http://twitter.com/search?q=%23%E3%81%93%E3%81%AE%E4%B8%96%E7%95%8C%E3%81%AE%E7%89%87%E9%9A%85%E3%81%AB',
#     'promoted_content': None,
#     'query': '%23%E3%81%93%E3%81%AE%E4%B8%96%E7%95%8C%E3%81%AE%E7%89%87%E9%9A%85%E3%81%AB',
#     'tweet_volume': None},
#    {'name': '#999DayUK',
#     'url': 'http://twitter.com/search?q=%23999DayUK',
#     'promoted_content': None,
#     'query': '%23999DayUK',
#     'tweet_volume': None},
#    {'name': '#pazar',
#     'url': 'http://twitter.com/search?q=%23pazar',
#     'promoted_content': None,
#     'query': '%23pazar',
#     'tweet_volume': 20311},
#    {'name': '#الصندوق_العقاري_قتل_احلامي',
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D8%B5%D9%86%D8%AF%D9%88%D9%82_%D8%A7%D9%84%D8%B9%D9%82%D8%A7%D8%B1%D9%8A_%D9%82%D8%AA%D9%84_%D8%A7%D8%AD%D9%84%D8%A7%D9%85%D9%8A',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%84%D8%B5%D9%86%D8%AF%D9%88%D9%82_%D8%A7%D9%84%D8%B9%D9%82%D8%A7%D8%B1%D9%8A_%D9%82%D8%AA%D9%84_%D8%A7%D8%AD%D9%84%D8%A7%D9%85%D9%8A',
#     'tweet_volume': None},
#    {'name': '#WhatMakesMeWonderfullyWeird',
#     'url': 'http://twitter.com/search?q=%23WhatMakesMeWonderfullyWeird',
#     'promoted_content': None,
#     'query': '%23WhatMakesMeWonderfullyWeird',
#     'tweet_volume': None},
#    {'name': '#Köthen',
#     'url': 'http://twitter.com/search?q=%23K%C3%B6then',
#     'promoted_content': None,
#     'query': '%23K%C3%B6then',
#     'tweet_volume': None},
#    {'name': '#MakeAMovieClean',
#     'url': 'http://twitter.com/search?q=%23MakeAMovieClean',
#     'promoted_content': None,
#     'query': '%23MakeAMovieClean',
#     'tweet_volume': None},
#    {'name': '#NCTzenSelcaDay',
#     'url': 'http://twitter.com/search?q=%23NCTzenSelcaDay',
#     'promoted_content': None,
#     'query': '%23NCTzenSelcaDay',
#     'tweet_volume': 45632},
#    {'name': '#鉄腕DASH',
#     'url': 'http://twitter.com/search?q=%23%E9%89%84%E8%85%95DASH',
#     'promoted_content': None,
#     'query': '%23%E9%89%84%E8%85%95DASH',
#     'tweet_volume': 15755},
#    {'name': '#شعورك_ببيت_قصيده',
#     'url': 'http://twitter.com/search?q=%23%D8%B4%D8%B9%D9%88%D8%B1%D9%83_%D8%A8%D8%A8%D9%8A%D8%AA_%D9%82%D8%B5%D9%8A%D8%AF%D9%87',
#     'promoted_content': None,
#     'query': '%23%D8%B4%D8%B9%D9%88%D8%B1%D9%83_%D8%A8%D8%A8%D9%8A%D8%AA_%D9%82%D8%B5%D9%8A%D8%AF%D9%87',
#     'tweet_volume': None},
#    {'name': '#DzielnicaPrzyszłość',
#     'url': 'http://twitter.com/search?q=%23DzielnicaPrzysz%C5%82o%C5%9B%C4%87',
#     'promoted_content': None,
#     'query': '%23DzielnicaPrzysz%C5%82o%C5%9B%C4%87',
#     'tweet_volume': None},
#    {'name': '#Sm테스트',
#     'url': 'http://twitter.com/search?q=%23Sm%ED%85%8C%EC%8A%A4%ED%8A%B8',
#     'promoted_content': None,
#     'query': '%23Sm%ED%85%8C%EC%8A%A4%ED%8A%B8',
#     'tweet_volume': None},
#    {'name': '#DüşündümDe',
#     'url': 'http://twitter.com/search?q=%23D%C3%BC%C5%9F%C3%BCnd%C3%BCmDe',
#     'promoted_content': None,
#     'query': '%23D%C3%BC%C5%9F%C3%BCnd%C3%BCmDe',
#     'tweet_volume': None},
#    {'name': '#HappyBirthdayAkshayKumar',
#     'url': 'http://twitter.com/search?q=%23HappyBirthdayAkshayKumar',
#     'promoted_content': None,
#     'query': '%23HappyBirthdayAkshayKumar',
#     'tweet_volume': 172393},
#    {'name': '#DomingoDetremuraSDV',
#     'url': 'http://twitter.com/search?q=%23DomingoDetremuraSDV',
#     'promoted_content': None,
#     'query': '%23DomingoDetremuraSDV',
#     'tweet_volume': 11936},
#    {'name': '#BeAdvised',
#     'url': 'http://twitter.com/search?q=%23BeAdvised',
#     'promoted_content': None,
#     'query': '%23BeAdvised',
#     'tweet_volume': None},
#    {'name': '#buitenhof',
#     'url': 'http://twitter.com/search?q=%23buitenhof',
#     'promoted_content': None,
#     'query': '%23buitenhof',
#     'tweet_volume': None},
#    {'name': '#9settembre',
#     'url': 'http://twitter.com/search?q=%239settembre',
#     'promoted_content': None,
#     'query': '%239settembre',
#     'tweet_volume': None}],
#   'as_of': '2018-09-09T12:49:45Z',
#   'created_at': '2018-09-09T12:42:44Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}]}]

# %%
trends=local_trends
print(type(trends))
print(list(trends[0].keys()))
print(trends[0]['trends'])
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['trends', 'as_of', 'created_at', 'locations']
# [{'name': '#shoppingdeals', 'url': 'http://twitter.com/search?q=%23shoppingdeals', 'promoted_content': None, 'query': '%23shoppingdeals', 'tweet_volume': None}, {'name': '#GivingTuesday', 'url': 'http://twitter.com/search?q=%23GivingTuesday', 'promoted_content': None, 'query': '%23GivingTuesday', 'tweet_volume': 32137}, {'name': '#OANN', 'url': 'http://twitter.com/search?q=%23OANN', 'promoted_content': None, 'query': '%23OANN', 'tweet_volume': None}, {'name': 'Congress', 'url': 'http://twitter.com/search?q=Congress', 'promoted_content': None, 'query': 'Congress', 'tweet_volume': 359220}, {'name': 'San Diego County', 'url': 'http://twitter.com/search?q=%22San+Diego+County%22', 'promoted_content': None, 'query': '%22San+Diego+County%22', 'tweet_volume': None}, {'name': '#sandiegoweather', 'url': 'http://twitter.com/search?q=%23sandiegoweather', 'promoted_content': None, 'query': '%23sandiegoweather', 'tweet_volume': None}, {'name': 'Tijuana', 'url': 'http://twitter.com/search?q=Tijuana', 'promoted_content': None, 'query': 'Tijuana', 'tweet_volume': 46081}, {'name': '#gotoreros', 'url': 'http://twitter.com/search?q=%23gotoreros', 'promoted_content': None, 'query': '%23gotoreros', 'tweet_volume': None}, {'name': 'George Perles', 'url': 'http://twitter.com/search?q=%22George+Perles%22', 'promoted_content': None, 'query': '%22George+Perles%22', 'tweet_volume': None}, {'name': 'South Lawn', 'url': 'http://twitter.com/search?q=%22South+Lawn%22', 'promoted_content': None, 'query': '%22South+Lawn%22', 'tweet_volume': None}, {'name': 'Felix Sater', 'url': 'http://twitter.com/search?q=%22Felix+Sater%22', 'promoted_content': None, 'query': '%22Felix+Sater%22', 'tweet_volume': None}, {'name': 'Maddox Ritch', 'url': 'http://twitter.com/search?q=%22Maddox+Ritch%22', 'promoted_content': None, 'query': '%22Maddox+Ritch%22', 'tweet_volume': None}, {'name': 'Darren Sproles', 'url': 'http://twitter.com/search?q=%22Darren+Sproles%22', 'promoted_content': None, 'query': '%22Darren+Sproles%22', 'tweet_volume': None}, {'name': 'danny ainge', 'url': 'http://twitter.com/search?q=%22danny+ainge%22', 'promoted_content': None, 'query': '%22danny+ainge%22', 'tweet_volume': None}, {'name': 'Paul Caneiro', 'url': 'http://twitter.com/search?q=%22Paul+Caneiro%22', 'promoted_content': None, 'query': '%22Paul+Caneiro%22', 'tweet_volume': None}, {'name': 'alea', 'url': 'http://twitter.com/search?q=alea', 'promoted_content': None, 'query': 'alea', 'tweet_volume': None}, {'name': 'President Putin', 'url': 'http://twitter.com/search?q=%22President+Putin%22', 'promoted_content': None, 'query': '%22President+Putin%22', 'tweet_volume': None}, {'name': 'Louisa May Alcott', 'url': 'http://twitter.com/search?q=%22Louisa+May+Alcott%22', 'promoted_content': None, 'query': '%22Louisa+May+Alcott%22', 'tweet_volume': None}, {'name': 'The 10 Best Books of 2018', 'url': 'http://twitter.com/search?q=%22The+10+Best+Books+of+2018%22', 'promoted_content': None, 'query': '%22The+10+Best+Books+of+2018%22', 'tweet_volume': None}, {'name': 'Citi Bike', 'url': 'http://twitter.com/search?q=%22Citi+Bike%22', 'promoted_content': None, 'query': '%22Citi+Bike%22', 'tweet_volume': None}, {'name': 'Trump-Xi', 'url': 'http://twitter.com/search?q=Trump-Xi', 'promoted_content': None, 'query': 'Trump-Xi', 'tweet_volume': None}, {'name': 'Abcde', 'url': 'http://twitter.com/search?q=Abcde', 'promoted_content': None, 'query': 'Abcde', 'tweet_volume': None}, {'name': 'Grimes', 'url': 'http://twitter.com/search?q=Grimes', 'promoted_content': None, 'query': 'Grimes', 'tweet_volume': 17262}, {'name': "I Don't Want to Shoot You", 'url': 'http://twitter.com/search?q=%22I+Don%27t+Want+to+Shoot+You%22', 'promoted_content': None, 'query': '%22I+Don%27t+Want+to+Shoot+You%22', 'tweet_volume': None}, {'name': '#Padres', 'url': 'http://twitter.com/search?q=%23Padres', 'promoted_content': None, 'query': '%23Padres', 'tweet_volume': None}, {'name': '#ThursdayThoughts', 'url': 'http://twitter.com/search?q=%23ThursdayT ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print((json.dumps(us_trends[:2], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "Michael Cohen",
#     "url": "http://twitter.com/search?q=%22Michael+Cohen%22",
#     "promoted_content": null,
#     "query": "%22Michael+Cohen%22",
#     "tweet_volume": 126716
#    },
#    {
#     "name": "#ThursdayThoughts",
#     "url": "http://twitter.com/search?q=%23ThursdayThoughts",
#     "promoted_content": null,
#     "query": "%23ThursdayThoughts",
#     "tweet_volume": 75154
#    },
#    {
#     "name": "#LARain",
#     "url": "http://twitter.com/search?q=%23LARain",
#     "promoted_content": null,
#     "query": "%23LARain",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ClickbaitFromThe80s",
#     "url": "http://twitter.com/search?q=%23ClickbaitFromThe80s",
#     "promoted_content": null,
#     "query": "%23ClickbaitFromThe80s",
#     "tweet_volume": null
#    },
#    {
#     "name": "George Perles",
#     "url": "http://twitter.com/search?q=%22George+Perles%22",
#     "promoted_content": null,
#     "query": "%22George+Perles%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BloombergHealthSummit",
#     "url": "http://twitter.com/search?q=%23BloombergHealthSummit",
#     "promoted_content": null,
#     "query": "%23BloombergHealthSummit",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HolidayVibes",
#     "url": "http://twitter.com/search?q=%23HolidayVibes",
#     "promoted_content": null,
#     "query": "%23HolidayVibes",
#     "tweet_volume": null
#    },
#    {
#     "name": "South Lawn",
#     "url": "http://twitter.com/search?q=%22South+Lawn%22",
#     "promoted_content": null,
#     "query": "%22South+Lawn%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Maddox Ritch",
#     "url": "http://twitter.com/search?q=%22Maddox+Ritch%22",
#     "promoted_content": null,
#     "query": "%22Maddox+Ritch%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Felix Sater",
#     "url": "http://twitter.com/search?q=%22Felix+Sater%22",
#     "promoted_content": null,
#     "query": "%22Felix+Sater%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Darren Sproles",
#     "url": "http://twitter.com/search?q=%22Darren+Sproles%22",
#     "promoted_content": null,
#     "query": "%22Darren+Sproles%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Citi Bike",
#     "url": "http://twitter.com/search?q=%22Citi+Bike%22",
#     "promoted_content": null,
#     "query": "%22Citi+Bike%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Mashable",
#     "url": "http://twitter.com/search?q=Mashable",
#     "promoted_content": null,
#     "query": "Mashable",
#     "tweet_volume": null
#    },
#    {
#     "name": "danny ainge",
#     "url": "http://twitter.com/search?q=%22danny+ainge%22",
#     "promoted_content": null,
#     "query": "%22danny+ainge%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Trump-Xi",
#     "url": "http://twitter.com/search?q=Trump-Xi",
#     "promoted_content": null,
#     "query": "Trump-Xi",
#     "tweet_volume": null
#    },
#    {
#     "name": "Paul Caneiro",
#     "url": "http://twitter.com/search?q=%22Paul+Caneiro%22",
#     "promoted_content": null,
#     "query": "%22Paul+Caneiro%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "alea",
#     "url": "http://twitter.com/search?q=alea",
#     "promoted_content": null,
#     "query": "alea",
#     "tweet_volume": null
#    },
#    {
#     "name": "President Putin",
#     "url": "http://twitter.com/search?q=%22President+Putin%22",
#     "promoted_content": null,
#     "query": "%22President+Putin%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Louisa May Alcott",
#     "url": "http://twitter.com/search?q=%22Louisa+May+Alcott%22",
#     "promoted_content": null,
#     "query": "%22Louisa+May+Alcott%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "The 10 Best Books of 2018",
#     "url": "http://twitter.com/search?q=%22The+10+Best+Books+of+2018%22",
#     "promoted_content": null,
#     "query": "%22The+10+Best+Books+of+2018%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Abcde",
#     "url": "http://twitter.com/search?q=Abcde",
#     "promoted_content": null,
#     "query": "Abcde",
#     "tweet_volume": null
#    },
#    {
#     "name": "Bernab\u00e9u",
#     "url": "http://twitter.com/search?q=Bernab%C3%A9u",
#     "promoted_content": null,
#     "query": "Bernab%C3%A9u",
#     "tweet_volume": 12351
#    },
#    {
#     "name": "Gesaffelstein",
#     "url": "http://twitter.com/search?q=Gesaffelstein",
#     "promoted_content": null,
#     "query": "Gesaffelstein",
#     "tweet_volume": null
#    },
#    {
#     "name": "Grimes",
#     "url": "http://twitter.com/search?q=Grimes",
#     "promoted_content": null,
#     "query": "Grimes",
#     "tweet_volume": 17387
#    },
#    {
#     "name": "I Don't Want to Shoot You",
#     "url": "http://twitter.com/search?q=%22I+Don%27t+Want+to+Shoot+You%22",
#     "promoted_content": null,
#     "query": "%22I+Don%27t+Want+to+Shoot+You%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Trump's Russia",
#     "url": "http://twitter.com/search?q=%22Trump%27s+Russia%22",
#     "promoted_content": null,
#     "query": "%22Trump%27s+Russia%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Don Jr.",
#     "url": "http://twitter.com/search?q=%22Don+Jr.%22",
#     "promoted_content": null,
#     "query": "%22Don+Jr.%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TheCustomerIsAlways",
#     "url": "http://twitter.com/search?q=%23TheCustomerIsAlways",
#     "promoted_content": null,
#     "query": "%23TheCustomerIsAlways",
#     "tweet_volume": null
#    },
#    {
#     "name": "#IfIWereTheDJ",
#     "url": "http://twitter.com/search?q=%23IfIWereTheDJ",
#     "promoted_content": null,
#     "query": "%23IfIWereTheDJ",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NOvsDAL",
#     "url": "http://twitter.com/search?q=%23NOvsDAL",
#     "promoted_content": null,
#     "query": "%23NOvsDAL",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ttevents",
#     "url": "http://twitter.com/search?q=%23ttevents",
#     "promoted_content": null,
#     "query": "%23ttevents",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TechSEOBoost",
#     "url": "http://twitter.com/search?q=%23TechSEOBoost",
#     "promoted_content": null,
#     "query": "%23TechSEOBoost",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ONC2018",
#     "url": "http://twitter.com/search?q=%23ONC2018",
#     "promoted_content": null,
#     "query": "%23ONC2018",
#     "tweet_volume": null
#    },
#    {
#     "name": "#IcarusFalls",
#     "url": "http://twitter.com/search?q=%23IcarusFalls",
#     "promoted_content": null,
#     "query": "%23IcarusFalls",
#     "tweet_volume": 17696
#    },
#    {
#     "name": "#StateImpact18",
#     "url": "http://twitter.com/search?q=%23StateImpact18",
#     "promoted_content": null,
#     "query": "%23StateImpact18",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AgSummit18",
#     "url": "http://twitter.com/search?q=%23AgSummit18",
#     "promoted_content": null,
#     "query": "%23AgSummit18",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AlliancePS18",
#     "url": "http://twitter.com/search?q=%23AlliancePS18",
#     "promoted_content": null,
#     "query": "%23AlliancePS18",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ExFR18",
#     "url": "http://twitter.com/search?q=%23ExFR18",
#     "promoted_content": null,
#     "query": "%23ExFR18",
#     "tweet_volume": null
#    },
#    {
#     "name": "#FastTVShows",
#     "url": "http://twitter.com/search?q=%23FastTVShows",
#     "promoted_content": null,
#     "query": "%23FastTVShows",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ForbesHealth",
#     "url": "http://twitter.com/search?q=%23ForbesHealth",
#     "promoted_content": null,
#     "query": "%23ForbesHealth",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NYFCC",
#     "url": "http://twitter.com/search?q=%23NYFCC",
#     "promoted_content": null,
#     "query": "%23NYFCC",
#     "tweet_volume": null
#    },
#    {
#     "name": "#LancetClimate18",
#     "url": "http://twitter.com/search?q=%23LancetClimate18",
#     "promoted_content": null,
#     "query": "%23LancetClimate18",
#     "tweet_volume": null
#    },
#    {
#     "name": "#communitiesovercoming",
#     "url": "http://twitter.com/search?q=%23communitiesovercoming",
#     "promoted_content": null,
#     "query": "%23communitiesovercoming",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ewaEquity18",
#     "url": "http://twitter.com/search?q=%23ewaEquity18",
#     "promoted_content": null,
#     "query": "%23ewaEquity18",
#     "tweet_volume": null
#    },
#    {
#     "name": "#WDPD2018",
#     "url": "http://twitter.com/search?q=%23WDPD2018",
#     "promoted_content": null,
#     "query": "%23WDPD2018",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NAISPoCC",
#     "url": "http://twitter.com/search?q=%23NAISPoCC",
#     "promoted_content": null,
#     "query": "%23NAISPoCC",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AtlanticWater",
#     "url": "http://twitter.com/search?q=%23AtlanticWater",
#     "promoted_content": null,
#     "query": "%23AtlanticWater",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SorryICantBecause",
#     "url": "http://twitter.com/search?q=%23SorryICantBecause",
#     "promoted_content": null,
#     "query": "%23SorryICantBecause",
#     "tweet_volume": null
#    },
#    {
#     "name": "#PuppyCam",
#     "url": "http://twitter.com/search?q=%23PuppyCam",
#     "promoted_content": null,
#     "query": "%23PuppyCam",
#     "tweet_volume": null
#    },
#    {
#     "name": "#202live",
#     "url": "http://twitter.com/search?q=%23202live",
#     "promoted_content": null,
#     "query": "%23202live",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2018-11-29T16:34:09Z",
#   "created_at": "2018-11-29T16:30:15Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['us'] = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

trends_set['san diego'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']]) 

trends_set['bra'] = set([trend['name'] 
                     for trend in bra_trends[0]['trends']]) 

trends_set['sp'] = set([trend['name'] 
                     for trend in localSP_trends[0]['trends']])

# %%
for loc in ['world','us','san diego','bra','sp']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
    print()
# Out:
# ('----------', 'world')
# Andrés Bello,#CumbreG20,#pezaopreso,#SorryJohan,#ClickbaitFromThe80s,#FelizJueves,George Harrison,#النصر_يظلم_يا_محمد_بن_سلمان,Dalas,Michetti,#الشباب_الاتفاق,#IcarusFalls,#PraSempreChape,#DimeLaVerdad,#WorldsMostBeautifulBride,#TabdeeliKay100Din,#いいにくいことを言う日,#ThursdayThoughts,Simón Vélez,#ProBowlVote,#くと打ってクリスマスって出たらリア充,#PBBOtsoyawan,Crónica,Serdar Aziz'e 3,#LARain,#اسمك_حقيقي_ع_تويتر,Pezão,秋篠宮さま,ANFP,#MeEmocionoCuando,#29Nov,키노시타,#خالد_المريخي_والمساعيد_بالرياض,#Cumbre1000,サキちゃん,Santiago Bernabéu,#insandeğilmiyim,#OTDirecto29NOV,ناصر الشمراني,#PacoIgnacioTaiboII,Michael Cohen,#BrexitDebate,#Reggae,#SomosLaAudiencia29N,Zé Rafael,#IndirectasDeQueMeGustas,#TBTRI,#Bodrum,Deutsche Bank,#كيف_تعرف_الصادق_من_الكاذب
#
# ('----------', 'us')
# #SorryICantBecause,#TheCustomerIsAlways,#PuppyCam,#ClickbaitFromThe80s,#FastTVShows,I Don't Want to Shoot You,Gesaffelstein,President Putin,danny ainge,#ForbesHealth,South Lawn,Grimes,#StateImpact18,#IcarusFalls,#NYFCC,#ewaEquity18,George Perles,Bernabéu,#AtlanticWater,Maddox Ritch,#ThursdayThoughts,Don Jr.,#LancetClimate18,Paul Caneiro,alea,Louisa May Alcott,#TechSEOBoost,#WDPD2018,#LARain,#HolidayVibes,#AlliancePS18,#IfIWereTheDJ,Darren Sproles,#AgSummit18,The 10 Best Books of 2018,Felix Sater,Trump-Xi,#BloombergHealthSummit,Mashable,#ExFR18,#202live,Trump's Russia,#NOvsDAL,Citi Bike,#ONC2018,Michael Cohen,#communitiesovercoming,#ttevents,Abcde,#NAISPoCC
#
# ('----------', 'san diego')
# Congress,#SorryICantBecause,#TheCustomerIsAlways,#ClickbaitFromThe80s,Tijuana,I Don't Want to Shoot You,#shoppingdeals,President Putin,danny ainge,#ForbesHealth,South Lawn,Grimes,#StateImpact18,#IcarusFalls,#NYFCC,#ewaEquity18,George Perles,#AtlanticWater,Maddox Ritch,#ThursdayThoughts,#LancetClimate18,Paul Caneiro,alea,Louisa May Alcott,#TechSEOBoost,San Diego County,#WDPD2018,#LARain,#Padres,#HolidayVibes,#naispocc,#AlliancePS18,#IfIWereTheDJ,Darren Sproles,#AgSummit18,#OANN,The 10 Best Books of 2018,Felix Sater,#gotoreros,Trump-Xi,#BloombergHealthSummit,#ExFR18,#NOvsDAL,Citi Bike,#ONC2018,#sandiegoweather,#communitiesovercoming,#ttevents,#GivingTuesday,Abcde
#
# ('----------', 'bra')
# #pezaopreso,#hojeemdia,Cabral,IBGE,Batalhão,Tirei Filmes,Desde 1998,#HowWeDoIt,#BBdebate,George Harrison,Grimes,#HosanaBrasil,#PraSempreChape,#IcarusFalls,Eduardo Paes,De Repente 30,#Wind_flower,#IntroNathanBarone,Mayra Cardi,Francisco Dornelles,Janio de Freitas,João César,#GOT7_Miracle,Pezão,#EuropaLeagueFOXSports,#malhaçãonoviva,#MileysBack,#GoodFormRemix,#tamojuntobmd,#QuintaDetremuraSDV,Freixo,Maracanã,Se o Renato,Contagem,Hinode,Abel,SAIBA MAIS,Santiago Bernabéu,ASSESSOR,moreira franco,Tirei Emo,#nessefimdeanoeuvou,Alerj,Alckmin,Zé Rafael,#TBTRI,Goethe
#
# ('----------', 'sp')
# #pezaopreso,#hojeemdia,Cabral,IBGE,Batalhão,Tirei Filmes,Desde 1998,#HowWeDoIt,#BBdebate,George Harrison,Grimes,#HosanaBrasil,#PraSempreChape,#IcarusFalls,Eduardo Paes,De Repente 30,#Wind_flower,#IntroNathanBarone,Mayra Cardi,Francisco Dornelles,Janio de Freitas,João César,#GOT7_Miracle,Pezão,#EuropaLeagueFOXSports,#malhaçãonoviva,#MileysBack,#GoodFormRemix,#tamojuntobmd,#QuintaDetremuraSDV,Freixo,Maracanã,Se o Renato,Contagem,Abel,Hinode,SAIBA MAIS,Santiago Bernabéu,ASSESSOR,moreira franco,Tirei Emo,#nessefimdeanoeuvou,Alerj,Alckmin,Zé Rafael,#TBTRI,Goethe,Natal

# %%
print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))
print()
print(('='*10,'intersection of us and san-diego'))
print((trends_set['san diego'].intersection(trends_set['us'])))
print()
print(('='*10,'intersection of world and bra'))
print((trends_set['world'].intersection(trends_set['bra'])))
print()
print(('='*10,'intersection of bra and sp'))
print((trends_set['bra'].intersection(trends_set['sp'])))
print()
print(('='*10,'intersection of us and bra'))
print((trends_set['bra'].intersection(trends_set['us'])))
print()
print(('='*10,'intersection of sp and san-diego'))
print((trends_set['san diego'].intersection(trends_set['sp'])))
# Out:
# ('==========', 'intersection of world and us')
# {'#WhatMakesMeWonderfullyWeird', '#SanMarinoGP', '#MakeAMovieClean', '#BeAdvised', '#SundayMorning'}
#
# ('==========', 'intersection of us and san-diego')
# {'Start With the Library', '#Florence', 'Jorge Lopez', 'Arizona State', '#WhatMakesMeWonderfullyWeird', '#SanMarinoGP', '#UKvsUF', 'Football Sunday', 'Clemson', '#CLEMvsTAMU', '#NB5thAveMile', 'Herm Edwards', '#HackLearning', '#BeAdvised', 'Spider-Man', 'Kellen Mond', '#BallsAreBestWhen', '#xoxofest', 'WIDOWS', 'Amber Guyger', '#UFC228', '#GarciaPorter', 'Cardi', '#PSUvsPITT', 'Samford', 'George Zimmerman', '#NYFW', '#SteelersNation', 'Elon Musk', '#PowerFinale', '#UGAvsSC', 'N. Korea', 'Sparty', 'Texas A&M', '#ShakespeareSunday', '#plaidshirtguy', '#MakeAMovieClean', '#Caturday', '#SundayMorning', '#RiseForClimate', 'Gators'}
#
# ('==========', 'intersection of world and bra')
# {'#DomingoDetremuraSDV'}
#
# ('==========', 'intersection of bra and sp')
# {'#AltasHoras', '#ASU2018', 'Eu Sou Lula', 'Dia de Grêmio', '#KeepBreathinAriana', 'Mourão', 'Diego Ribas', '#ufc228nocombate', '#DomingoDetremuraSDV', 'Serena', 'Magrão', 'Bahia', '#askmarvel', 'HOJE TEM CORINTHIANS', 'Everton Felipe', 'Globo Rural', '#CBLoL', '#BakeOffBrasil', '#MAMAMOOnoBrasil', '#ForçaBolsonaro', 'DIA DE INTER', 'Titan', 'Anitta e Thiago Magalhães', '#NobodyKnows', 'Douglas Costa', 'Vamos São Paulo', '#TVDnoSBT', 'Dia de Palmeiras', '#7deSetembro', 'Villas Bôas', '#SoTocaTop', '#NYFW', 'Graça Araújo', 'Cardi B', '#PCAs', '#motogpnosportv', 'Sport x Cruzeiro', 'Renê', 'Sierra Burgess', '#fcseguindofc', 'Brtt', '#StaySelcaDay', '#lulaÉPresidiario', 'Firmino', '#1000DaysWithout1D'}
#
# ('==========', 'intersection of us and bra')
# {'#NYFW'}
#
# ('==========', 'intersection of sp and san-diego')
# {'Serena', '#NYFW'}

# %% [markdown]
# ## Example 5. Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter

# %%
q = '#WhatMakesMeWonderfullyWeird' 

number = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=number)

statuses = search_results['statuses']

# %%
len(statuses)
#print(statuses)
# Out:
# 92

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 83

# %%
[s['text'] for s in search_results['statuses']]
# Out:
# ['RT @elizettezamora: I can turn any conversation into an awkward one!  #WhatMakesMeWonderfullyWeird',
#  'I love to go grocery shopping. I find it therapeutic \n#WhatMakesMeWonderfullyWeird',
#  'I can turn any conversation to something geeky  #WhatMakesMeWonderfullyWeird https://t.co/7IRKIPQLoQ',
#  'RT @TangledHotMess: #WhatMakesMeWonderfullyWeird\n\nI talk to all of my plants.',
#  'RT @elizettezamora: I can turn any conversation into an awkward one!  #WhatMakesMeWonderfullyWeird',
#  'RT @BekeAbe: #WhatMakesMeWonderfullyWeird My mind !',
#  'If you do not cling to #YHWH and his Holy #Torah,  #people and their disgusting system will do with you whatever  t… https://t.co/Itzg9FUdpr',
#  'RT @ankitGyVerma: weird things\n\n#WhatMakesMeWonderfullyWeird https://t.co/IaUvDbFSdN',
#  'I like big butts and I cannot lie\n#WhatMakesMeWonderfullyWeird',
#  'RT @bigmacher: #WhatMakesMeWonderfullyWeird\n\nI love taking pennies, but I hate leaving pennies (what if I need that penny later??)',
#  "RT @JanChiLing2: #WhatMakesMeWonderfullyWeird\nI'm a world-famous celebrity hiding behind this highly exclusive little Twitter account.",
#  '#WhatMakesMeWonderfullyWeird My mind !',
#  'I am a sucker for red poppy prints. I could wear red poppy prints from head to toe. But my husband says to stick ju… https://t.co/DP2wMwwDoi',
#  '#WhatMakesMeWonderfullyWeird\n\nI talk to all of my plants.',
#  'Everything. #WhatMakesMeWonderfullyWeird',
#  'I suck at accents but I can imitate everyone I meet. #WhatMakesMeWonderfullyWeird',
#  '#WhatMakesMeWonderfullyWeird\nI do Rockette kicks in the kitchen while waiting for food. https://t.co/ogaG196ure',
#  "#WhatMakesMeWonderfullyWeird\nI'm a world-famous celebrity hiding behind this highly exclusive little Twitter account.",
#  'RT @coolcam101: The way I make an entrance.\n #WhatMakesMeWonderfullyWeird https://t.co/KbkRDGS8n3',
#  '#WhatMakesMeWonderfullyWeird\nI say I am and #gish agrees😜🤓😘\n@RandomActsOrg https://t.co/t7YDLbxCgS',
#  '#whatmakesmewonderfullyweird The people who died last year may not be dead today this time.',
#  'RT @UnknownWr1ter: I’ll use word play more than 9 times to try to make you laugh, even when no pun in ten did.\n\nI’ll show myself out. \n#Wha…',
#  'RT @CuteLazy_Panda: #WhatMakesMeWonderfullyWeird\nI still play like a kid. https://t.co/M9UBmdyNi4',
#  "I'm Jahid and I'm a professional graphic designer.If you need any logo design please contact with me.\nHere is my li… https://t.co/lMoD2j0GZU",
#  '#whatmakesmewonderfullyweird\n\nI have never had a drink of alcohol in my life\nI get drunk on life\nLOL https://t.co/I26NiNNzK1',
#  'RT @DUPONTBLUES: #WhatMakesMeWonderfullyWeird \nSee how much fun indoors can be?  https://t.co/l8JPLZ5Z95',
#  'I blend salsa before I eat it. I don’t like chunks of tomatoes.\n #WhatMakesMeWonderfullyWeird',
#  'Every time I open my mouth 👄#WhatMakesMeWonderfullyWeird',
#  '#WhatMakesMeWonderfullyWeird Some call me Ripper T\n\nCause I could sing like Ripper &amp; spin like Booker\n\n(Side Note:… https://t.co/uzRirI1nI6',
#  'RT @whirledpeas4me: #WhatMakesMeWonderfullyWeird is that other weirdos feel like home to me and I am so proud to call some of  you weirdos…',
#  'RT @coolcam101: My Alter Ego.\n #WhatMakesMeWonderfullyWeird https://t.co/eEJSoOEHg3',
#  'Hate tomatoes .Love cherry tomatoes 🍅 \n#WhatMakesMeWonderfullyWeird',
#  'everything 😃 #WhatMakesMeWonderfullyWeird',
#  'RT @Jreedsy: I laugh to myself at something funny I said yesterday. \n#WhatMakesMeWonderfullyWeird',
#  'RT @elizettezamora: I can turn any conversation into an awkward one!  #WhatMakesMeWonderfullyWeird',
#  'RT @MrRaceBannon: I’m a 40 yr old man who babysits two kids and a dog  #WhatMakesMeWonderfullyWeird https://t.co/YXiQte6Hf6',
#  'RT @hashtag_darren: I’m no magician but I can make people who care about me disappear #WhatMakesMeWonderfullyWeird',
#  '#WhatMakesMeWonderfullyWeird All the coffee',
#  'RT @coolcam101: I never told anyone I was a bear.\n #WhatMakesMeWonderfullyWeird https://t.co/3tY30Gh9S2',
#  'RT @DonnaMarieConn3: I once ate nothing but Tuna sandwiches for an entire year. #WhatMakesMeWonderfullyWeird https://t.co/T12VHzqKqk',
#  'Makes you laugh unconditionally #WhatMakesMeWonderfullyWeird',
#  '#WhatMakesMeWonderfullyWeird\nI talk to strangers as if I know them.',
#  'RT @lilGiannis: I play games while studying and I study while playing games 👀\n#WhatMakesMeWonderfullyWeird',
#  'I named my GPS Stella. \nWhen I yell at her, I do my best Marlon Brando impression. 😜\n#WhatMakesMeWonderfullyWeird',
#  "RT @AngelaMiroddi: #WhatMakesMeWonderfullyWeird I'm not afraid to act like a fool to make people laugh",
#  'RT @UnknownWr1ter: I’ll use word play more than 9 times to try to make you laugh, even when no pun in ten did.\n\nI’ll show myself out. \n#Wha…',
#  '#WhatMakesMeWonderfullyWeird is that other weirdos feel like home to me and I am so proud to call some of  you weir… https://t.co/5BrfON07Um',
#  'I prefer the company of animals over humans\n\n #WhatMakesMeWonderfullyWeird',
#  'RT @KiddStClair: Hate onions. Love onion rings\n\n#WhatMakesMeWonderfullyWeird',
#  'RT @KARENSTEVER: #SundayMorning #WhatMakesMeWonderfullyWeird https://t.co/lNEfmXybWY',
#  'RT @Mymeaneviltwin: #WhatMakesMeWonderfullyWeird I can be crying like the world is about to end and still say something silly that will mak…',
#  "Being right handed, but generally when/while stage acting I'm more left handed... #WhatMakesMeWonderfullyWeird",
#  'Being myself even in great adversity!#WhatMakesMeWonderfullyWeird',
#  'RT @thestacitalley: #WhatMakesMeWonderfullyWeird         ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀       I have over 700 photos of my dog in my phone. #Igo…',
#  '#WhatMakesMeWonderfullyWeird I enjoy long conversations with myself',
#  'This hashtag is all about me\n\n#WhatMakesMeWonderfullyWeird',
#  'I have an obsession with beavers #WhatMakesMeWonderfullyWeird',
#  'I hate ranch dressing but love ranch doritos\n#WhatMakesMeWonderfullyWeird',
#  '#WhatMakesMeWonderfullyWeird\n\nSliced chicken, pepperoni, black olives and mayo sub on Italian herb and cheese bread… https://t.co/LRzUZ3bb5t',
#  'RT @bigmacher: #WhatMakesMeWonderfullyWeird \n\nI crack up at the same jokes over and over again',
#  '#WhatMakesMeWonderfullyWeird \nI’m not afraid of clowns, but puppets are freaking terrifying. So creepy, so so creepy.',
#  'RT @coolcam101: I never told anyone I was a bear.\n #WhatMakesMeWonderfullyWeird https://t.co/3tY30Gh9S2',
#  'RT @MitchwMitch: I sing and speak Spanish to my dog....and he understands me!\n#WhatMakesMeWonderfullyWeird https://t.co/X1DFj4GoP3',
#  'RT @coolcam101: The way I make an entrance.\n #WhatMakesMeWonderfullyWeird https://t.co/KbkRDGS8n3',
#  'RT @bachelruckley: My obsession with novelty egg cups\n#WhatMakesMeWonderfullyWeird https://t.co/N2kJwlgAJA',
#  'I wake up at 5:30 a.m. every weekday and 6:30 a.m. on the weekends. All without an alarm\n#WhatMakesMeWonderfullyWeird',
#  'RT @Billielilili: I completely change my personality when I go abroad. #WhatMakesMeWonderfullyWeird',
#  'RT @AdyS49: #WhatMakesMeWonderfullyWeird my third nipple',
#  'RT @coolcam101: I never told anyone I was a bear.\n #WhatMakesMeWonderfullyWeird https://t.co/3tY30Gh9S2',
#  '#WhatMakesMeWonderfullyWeird \nMy mind https://t.co/taK4YDryIR',
#  'RT @coolcam101: The way I make an entrance.\n #WhatMakesMeWonderfullyWeird https://t.co/KbkRDGS8n3',
#  'RT @CuteLazy_Panda: #WhatMakesMeWonderfullyWeird\nMy dark sense of humor. 👇😂 https://t.co/pkIhdPukF5',
#  "#WhatMakesMeWonderfullyWeird I won't sleep on hotel sheets ... https://t.co/W5fK31SFLG",
#  '#WhatMakesMeWonderfullyWeird Me.And my other me.',
#  'RT @STACEY_SCHAEKEN: I like to stare at people.  #WhatMakesMeWonderfullyWeird https://t.co/8T8hmwOjZk',
#  'RT @KARENSTEVER: #SundayMorning #WhatMakesMeWonderfullyWeird https://t.co/lNEfmXybWY',
#  '#WhatMakesMeWonderfullyWeird https://t.co/G1U9TGxKQo',
#  "RT @DaSkrambledEgg: I dip French fries in my frosty at Wendy's #WhatMakesMeWonderfullyWeird",
#  'RT @JenTusch: I am a 51 year old Jewish mother but I sometimes break out into 80s rap songs at inopportune moments.  #WhatMakesMeWonderfull…',
#  'RT @CuteLazy_Panda: #WhatMakesMeWonderfullyWeird\nI still play like a kid. https://t.co/M9UBmdyNi4',
#  "I can love my female friends without using them as my personal fuck toy....even when i can or want to....it's never… https://t.co/lpOle9yhsU",
#  'My dong has a knuckle 🤷🏼\u200d♂️ #WhatMakesMeWonderfullyWeird',
#  'I LOVE THE SMELL OF GAS STATION. \n\n#WhatMakesMeWonderfullyWeird',
#  'RT @TheTrueDocLove: Good morning and welcome to Sundays with Doc on the @HashtagRoundup app. Today is Wonderful Weirdos day and I want to k…',
#  'I sometimes act younger than I am\n#WhatMakesMeWonderfullyWeird',
#  'RT @lizard_lou: #WhatMakesMeWonderfullyWeird I have the craziest things happen to me 😂 https://t.co/YcW2ornsrq',
#  '#WhatMakesMeWonderfullyWeird\nI like coffee in bed. I believe in the importance of punctuating tweets and texts. Cats make everything better.',
#  '#WhatMakesMeWonderfullyWeird\nToday is the luckiest day of the year for people like me, whose lucky number is 9! #SundayMorning',
#  "#WhatMakesMeWonderfullyWeird I'm 6'2, 220, well built. However, petite girls are my weakness.",
#  "RT @iris_bestia: #WhatMakesMeWonderfullyWeird\nI don't know what you are talking about https://t.co/aMFDvqfacS",
#  "#WhatMakesMeWonderfullyWeird Dude, where's my cranium?\nI love the Dude where's my car tweets! https://t.co/6u3FRL0yPL",
#  '#WhatMakesMeWonderfullyWeird \n\nI am not at all worried about outer look at all. I am 18.']

# %%
# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))
# Out:
# {
#  "created_at": "Sun Sep 09 12:51:05 +0000 2018",
#  "id": 1038771774060515328,
#  "id_str": "1038771774060515328",
#  "text": "RT @elizettezamora: I can turn any conversation into an awkward one!  #WhatMakesMeWonderfullyWeird",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "WhatMakesMeWonderfullyWeird",
#     "indices": [
#      70,
#      98
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "elizettezamora",
#     "name": "Elizette Z",
#     "id": 702388539581984768,
#     "id_str": "702388539581984768",
#     "indices": [
#      3,
#      18
#     ]
#    }
#   ],
#   "urls": []
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 1038033019557171200,
#   "id_str": "1038033019557171200",
#   "name": "Just A Bearded Guy",
#   "screen_name": "JustAGuy90",
#   "location": "",
#   "description": "Just a guy who needed a place to escape the every day pressures of marriage, fatherhood, and adulthood.",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 24,
#   "friends_count": 78,
#   "listed_count": 0,
#   "created_at": "Fri Sep 07 11:55:32 +0000 2018",
#   "favourites_count": 163,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 65,
#   "lang": "en",
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "F5F8FA",
#   "profile_background_image_url": null,
#   "profile_background_image_url_https": null,
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/1038268843422969857/XHpYtn0z_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/1038268843422969857/XHpYtn0z_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/1038033019557171200/1536377557",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": false,
#   "default_profile": true,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Sun Sep 09 12:01:41 +0000 2018",
#   "id": 1038759345872363520,
#   "id_str": "1038759345872363520",
#   "text": "I can turn any conversation into an awkward one!  #WhatMakesMeWonderfullyWeird",
#   "truncated": false,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "WhatMakesMeWonderfullyWeird",
#      "indices": [
#       50,
#       78
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": []
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 702388539581984768,
#    "id_str": "702388539581984768",
#    "name": "Elizette Z",
#    "screen_name": "elizettezamora",
#    "location": "Texas ",
#    "description": "6:30 is the best time on a clock. Hands down. Tweet about hashtag games and boring stuff! sub game account: @TexanTags #gospursgo\ud83c\udfc0",
#    "url": "https://t.co/r3ZRM8D3Qk",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/r3ZRM8D3Qk",
#        "expanded_url": "https://twitter.com/search?q=from%3A%40elizettezamora%20-filter%3Areplies&s=09",
#        "display_url": "twitter.com/search?q=from%\u2026",
#        "indices": [
#         0,
#         23
#        ]
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 3540,
#    "friends_count": 1596,
#    "listed_count": 26,
#    "created_at": "Wed Feb 24 07:04:12 +0000 2016",
#    "favourites_count": 32906,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 38234,
#    "lang": "en",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "F5F8FA",
#    "profile_background_image_url": null,
#    "profile_background_image_url_https": null,
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1035190181962371072/Ltk5uNek_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1035190181962371072/Ltk5uNek_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/702388539581984768/1528461534",
#    "profile_link_color": "1DA1F2",
#    "profile_sidebar_border_color": "C0DEED",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": true,
#    "default_profile": true,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 50,
#   "favorite_count": 101,
#   "favorited": false,
#   "retweeted": false,
#   "lang": "en"
#  },
#  "is_quote_status": false,
#  "retweet_count": 50,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "lang": "en"
# }

# %%
# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[0]
#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'])
print(t['retweeted'])
# Out:
# 50
# False

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "RT @elizettezamora: I can turn any conversation into an awkward one!  #WhatMakesMeWonderfullyWeird",
#  "I love to go grocery shopping. I find it therapeutic \n#WhatMakesMeWonderfullyWeird",
#  "I can turn any conversation to something geeky  #WhatMakesMeWonderfullyWeird https://t.co/7IRKIPQLoQ",
#  "RT @TangledHotMess: #WhatMakesMeWonderfullyWeird\n\nI talk to all of my plants.",
#  "RT @BekeAbe: #WhatMakesMeWonderfullyWeird My mind !"
# ]
# [
#  "elizettezamora",
#  "TangledHotMess",
#  "BekeAbe",
#  "ankitGyVerma",
#  "bigmacher"
# ]
# [
#  "WhatMakesMeWonderfullyWeird",
#  "WhatMakesMeWonderfullyWeird",
#  "WhatMakesMeWonderfullyWeird",
#  "WhatMakesMeWonderfullyWeird",
#  "WhatMakesMeWonderfullyWeird"
# ]
# [
#  "RT",
#  "@elizettezamora:",
#  "I",
#  "can",
#  "turn"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()
# Out:
# [('#WhatMakesMeWonderfullyWeird', 72), ('I', 71), ('RT', 35), ('to', 23), ('my', 20), ('and', 18), ('of', 12), ('like', 12), ('a', 12), ('the', 12)]
#
# [('coolcam101', 3), ('bigmacher', 2), ('CuteLazy_Panda', 2), ('elizettezamora', 1), ('TangledHotMess', 1), ('BekeAbe', 1), ('ankitGyVerma', 1), ('JanChiLing2', 1), ('RandomActsOrg', 1), ('UnknownWr1ter', 1)]
#
# [('WhatMakesMeWonderfullyWeird', 74), ('whatmakesmewonderfullyweird', 2), ('SundayMorning', 2), ('YHWH', 1), ('Torah', 1), ('people', 1), ('gish', 1)]

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^30} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:30} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])
# Out:
#              Word              | Count
# ****************************************
# #WhatMakesMeWonderfullyWeird   |     72
# I                              |     71
# RT                             |     35
# to                             |     23
# my                             |     20
# and                            |     18
# of                             |     12
# like                           |     12
# a                              |     12
# the                            |     12
#
#          Screen Name           | Count
# ****************************************
# coolcam101                     |      3
# bigmacher                      |      2
# CuteLazy_Panda                 |      2
# elizettezamora                 |      1
# TangledHotMess                 |      1
# BekeAbe                        |      1
# ankitGyVerma                   |      1
# JanChiLing2                    |      1
# RandomActsOrg                  |      1
# UnknownWr1ter                  |      1
#
#            Hashtag             | Count
# ****************************************
# WhatMakesMeWonderfullyWeird    |     74
# whatmakesmewonderfullyweird    |      2
# SundayMorning                  |      2
# YHWH                           |      1
# Torah                          |      1
# people                         |      1
# gish                           |      1

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*80)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[:10])
# Out:
#  Count  |   Screen Name   | Text
# ********************************************************************************
#   50    | elizettezamora  | RT @elizettezamora: I can turn any conversation in
#         |                 | to an awkward one!  #WhatMakesMeWonderfullyWeird
#   35    |   KiddStClair   | RT @KiddStClair: Hate onions. Love onion rings\\#W
#         |                 | hatMakesMeWonderfullyWeird
#   24    |    bigmacher    | RT @bigmacher: #WhatMakesMeWonderfullyWeird\\I lov
#         |                 | e taking pennies, but I hate leaving pennies (what
#         |                 |  if I need that penny later??)
#   24    | TheTrueDocLove  | RT @TheTrueDocLove: Good morning and welcome to Su
#         |                 | ndays with Doc on the @HashtagRoundup app. Today i
#         |                 | s Wonderful Weirdos day and I want to k…
#   21    |   coolcam101    | RT @coolcam101: The way I make an entrance.\ #What
#         |                 | MakesMeWonderfullyWeird https://t.co/KbkRDGS8n3
#   17    | DaSkrambledEgg  | RT @DaSkrambledEgg: I dip French fries in my frost
#         |                 | y at Wendy's #WhatMakesMeWonderfullyWeird
#   16    |  MrRaceBannon   | RT @MrRaceBannon: I’m a 40 yr old man who babysits
#         |                 |  two kids and a dog  #WhatMakesMeWonderfullyWeird
#         |                 | https://t.co/YXiQte6Hf6
#   13    |    JenTusch     | RT @JenTusch: I am a 51 year old Jewish mother but
#         |                 |  I sometimes break out into 80s rap songs at inopp
#         |                 | ortune moments.  #WhatMakesMeWonderfull…
#   12    |    bigmacher    | RT @bigmacher: #WhatMakesMeWonderfullyWeird \\I cr
#         |                 | ack up at the same jokes over and over again
#   11    |   coolcam101    | RT @coolcam101: I never told anyone I was a bear.\
#         |                 |  #WhatMakesMeWonderfullyWeird https://t.co/3tY30Gh
#         |                 | 9S2
